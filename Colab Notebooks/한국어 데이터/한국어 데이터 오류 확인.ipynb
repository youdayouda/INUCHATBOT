# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive
# Out:
# /content/drive

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
cd cdQA-bert_qa_vGPU
# Out:
# /content/drive/MyDrive/cdQA-bert_qa_vGPU

# %%
pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/cdQA-bert_qa_vGPU
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from cdqa==0.0.1) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from cdqa==0.0.1) (1.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from cdqa==0.0.1) (1.3.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from cdqa==0.0.1) (3.7.1)
# Collecting pytorch-pretrained-bert (from cdqa==0.0.1)
#   Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from cdqa==0.0.1) (4.11.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from cdqa==0.0.1) (4.9.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from cdqa==0.0.1) (4.66.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from cdqa==0.0.1) (3.9.0)
# Collecting wget (from cdqa==0.0.1)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting PyGithub (from cdqa==0.0.1)
#   Downloading PyGithub-2.1.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from cdqa==0.0.1) (2.2.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->cdqa==0.0.1) (2.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask->cdqa==0.0.1) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask->cdqa==0.0.1) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask->cdqa==0.0.1) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask->cdqa==0.0.1) (8.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa==0.0.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa==0.0.1) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa==0.0.1) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa==0.0.1) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa==0.0.1) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa==0.0.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa==0.0.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa==0.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->cdqa==0.0.1) (2023.3.post1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->cdqa==0.0.1) (0.2.12)
# Collecting pynacl>=1.4.0 (from PyGithub->cdqa==0.0.1)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from PyGithub->cdqa==0.0.1) (2.31.0)
# Collecting pyjwt[crypto]>=2.4.0 (from PyGithub->cdqa==0.0.1)
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from PyGithub->cdqa==0.0.1) (4.5.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from PyGithub->cdqa==0.0.1) (2.0.7)
# Collecting Deprecated (from PyGithub->cdqa==0.0.1)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert->cdqa==0.0.1) (2.1.0+cu118)
# Collecting boto3 (from pytorch-pretrained-bert->cdqa==0.0.1)
#   Downloading boto3-1.33.6-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert->cdqa==0.0.1) (2023.6.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->cdqa==0.0.1) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->cdqa==0.0.1) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->flask->cdqa==0.0.1) (2.1.3)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub->cdqa==0.0.1) (41.0.7)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pynacl>=1.4.0->PyGithub->cdqa==0.0.1) (1.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->cdqa==0.0.1) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14.0->PyGithub->cdqa==0.0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14.0->PyGithub->cdqa==0.0.1) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14.0->PyGithub->cdqa==0.0.1) (2023.11.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert->cdqa==0.0.1) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert->cdqa==0.0.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert->cdqa==0.0.1) (3.2.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert->cdqa==0.0.1) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert->cdqa==0.0.1) (2.1.0)
# Collecting botocore<1.34.0,>=1.33.6 (from boto3->pytorch-pretrained-bert->cdqa==0.0.1)
#   Downloading botocore-1.33.6-py3-none-any.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 33.8 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->pytorch-pretrained-bert->cdqa==0.0.1)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.9.0,>=0.8.2 (from boto3->pytorch-pretrained-bert->cdqa==0.0.1)
#   Downloading s3transfer-0.8.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->PyGithub->cdqa==0.0.1) (1.14.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub->cdqa==0.0.1) (2.21)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.1->pytorch-pretrained-bert->cdqa==0.0.1) (1.3.0)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=dfaee49398a94f8646294782eeafe1a54d5a030ef2fd7963923e28bfa766641c
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget, pyjwt, jmespath, Deprecated, pynacl, botocore, s3transfer, PyGithub, boto3, pytorch-pretrained-bert, cdqa
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
#   Running setup.py develop for cdqa
# Successfully installed Deprecated-1.2.14 PyGithub-2.1.1 boto3-1.33.6 botocore-1.33.6 cdqa-0.0.1 jmespath-1.0.1 pyjwt-2.8.0 pynacl-1.5.0 pytorch-pretrained-bert-0.6.2 s3transfer-0.8.2 wget-3.2

# %%
pip install cdqa
# Out:
# Requirement already satisfied: cdqa in /content/drive/MyDrive/cdQA-bert_qa_vGPU (0.0.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from cdqa) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from cdqa) (1.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from cdqa) (1.3.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from cdqa) (3.7.1)
# Requirement already satisfied: pytorch-pretrained-bert in /usr/local/lib/python3.10/dist-packages (from cdqa) (0.6.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from cdqa) (4.11.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from cdqa) (4.9.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from cdqa) (4.66.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from cdqa) (3.9.0)
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (from cdqa) (3.2)
# Requirement already satisfied: PyGithub in /usr/local/lib/python3.10/dist-packages (from cdqa) (2.1.1)
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from cdqa) (2.2.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->cdqa) (2.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask->cdqa) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask->cdqa) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask->cdqa) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask->cdqa) (8.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdqa) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->cdqa) (2023.3.post1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->cdqa) (0.2.12)
# Requirement already satisfied: pynacl>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from PyGithub->cdqa) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from PyGithub->cdqa) (2.31.0)
# Requirement already satisfied: pyjwt[crypto]>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from PyGithub->cdqa) (2.8.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from PyGithub->cdqa) (4.5.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from PyGithub->cdqa) (2.0.7)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.10/dist-packages (from PyGithub->cdqa) (1.2.14)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert->cdqa) (2.1.0+cu118)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert->cdqa) (1.33.6)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert->cdqa) (2023.6.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->cdqa) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->cdqa) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->flask->cdqa) (2.1.3)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub->cdqa) (41.0.7)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pynacl>=1.4.0->PyGithub->cdqa) (1.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->cdqa) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14.0->PyGithub->cdqa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14.0->PyGithub->cdqa) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14.0->PyGithub->cdqa) (2023.11.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert->cdqa) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert->cdqa) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert->cdqa) (3.2.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert->cdqa) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert->cdqa) (2.1.0)
# Requirement already satisfied: botocore<1.34.0,>=1.33.6 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch-pretrained-bert->cdqa) (1.33.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch-pretrained-bert->cdqa) (1.0.1)
# Requirement already satisfied: s3transfer<0.9.0,>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch-pretrained-bert->cdqa) (0.8.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->PyGithub->cdqa) (1.14.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub->cdqa) (2.21)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.1->pytorch-pretrained-bert->cdqa) (1.3.0)

# %%
import os
import pandas as pd
from ast import literal_eval

from cdqa.utils.filters import filter_paragraphs
from cdqa.pipeline.cdqa_sklearn import QAPipeline
# Out:
# /content/drive/MyDrive/cdQA-bert_qa_vGPU/cdqa/reader/bertqa_sklearn.py:36: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
df = pd.read_csv('./data/korean.csv', encoding='cp949',converters={'paragraphs': literal_eval}, error_bad_lines=False)

df = filter_paragraphs(df)
df['content'] = df['paragraphs'].apply(lambda x: ' '.join(x))
df.head()
# Out:
# <ipython-input-8-e4a5de34dc8d>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('./data/korean.csv', encoding='cp949',converters={'paragraphs': literal_eval}, error_bad_lines=False)
#   category1 category2 category3  category4   title  \
# 0        대학      공과대학     전자공학과        NaN   전자공학과
# 1        대학      공과대학     안전공학과        NaN   안전공학과
# 2        대학    예술체육대학     디자인학부        NaN   디자인학부
# 3        대학    예술체육대학    공연예술학과        NaN  공연예술학과
# 4        대학      사범대학     수학교육과        NaN   수학교육과
#
#                                         url  \
# 0  https://www.inu.ac.kr/inu/782/subview.do
# 1  https://www.inu.ac.kr/inu/785/subview.do
# 2  https://www.inu.ac.kr/inu/799/subview.do
# 3  https://www.inu.ac.kr/inu/800/subview.do
# 4  https://www.inu.ac.kr/inu/807/subview.do
#
#                                           paragraphs  \
# 0  [인천대학교의 국립대 전환, 송도 캠퍼스로의 이전과 더불어 전자공학과는 2024년 ...
# 1  [안전공학(Safety Engineering)은 다양하고 대형화 되어가고 있는 각종...
# 2  [또한 전문분야로 시각디자인, 영상디자인, 포장디자인, 일러스트레이션, 애니메이션,...
# 3  [21세기 현대 사회에 있어 중요한 화두가 된 문화예술을 위해 연기와 무용을 중심으...
# 4  [특히 수학교사의 기본 소양인 수학적 지식과 능력을 키우기 위하여 현대 수학의 학문...
#
#                                              content
# 0  인천대학교의 국립대 전환, 송도 캠퍼스로의 이전과 더불어 전자공학과는 2024년 전...
# 1  안전공학(Safety Engineering)은 다양하고 대형화 되어가고 있는 각종 ...
# 2  또한 전문분야로 시각디자인, 영상디자인, 포장디자인, 일러스트레이션, 애니메이션, ...
# 3  21세기 현대 사회에 있어 중요한 화두가 된 문화예술을 위해 연기와 무용을 중심으로...
# 4  특히 수학교사의 기본 소양인 수학적 지식과 능력을 키우기 위하여 현대 수학의 학문적...
